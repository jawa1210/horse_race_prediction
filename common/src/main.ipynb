# %%
import scraping
import pickle
import create_rawdf
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
autoreload

# %% [markdown]
# #データを取得

# %% [markdown]
# #開催日を取得

# %%
kaisai_date_list = scraping.scrape_kaisai_date(from_="2023-01", to_="2024-12")
# Out:
#   0%|          | 0/24 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 kaisai_date_list = scraping.scrape_kaisai_date(from_="2023-01", to_="2024-12")
#
# File ~/horse/keiba_new/common/src/scraping.py:33, in scrape_kaisai_date(from_, to_)
#      31 headers = {"User-Agent": "Mozilla/5.0"}
#      32 request = Request(url, headers=headers)
# ---> 33 html = urlopen(request).read()  # スクレイピング
#      34 time.sleep(1)
#      35 soup = BeautifulSoup(html, "lxml")
#
# File /usr/lib/python3.10/urllib/request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File /usr/lib/python3.10/urllib/request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
# ...

# %%
race_id_list=scraping.scrape_race_id_list(kaisai_date_list)
# Out:
#   0%|          | 0/213 [00:00<?, ?it/s]

# %%
with open("race_id_list.pickle","wb") as f:
    pickle.dump(race_id_list,f)

# %% [markdown]
# ## raceの取得

# %%
with open("race_id_list.pickle","rb") as f:
    race_id_list=pickle.load(f)

# %%
html_paths_race=scraping.scrape_html_race(race_id_list=race_id_list)
# Out:
#   0%|          | 0/6910 [00:00<?, ?it/s]
# skipped:202306010101
# skipped:202306010102
# skipped:202306010103
# skipped:202306010104
# skipped:202306010105
# skipped:202306010106
# skipped:202306010107
# skipped:202306010108
# skipped:202306010109
# skipped:202306010110
# skipped:202306010111
# skipped:202306010112
# skipped:202307010101
# skipped:202307010102
# skipped:202307010103
# skipped:202307010104
# skipped:202307010105
# skipped:202307010106
# skipped:202307010107
# skipped:202307010108
# skipped:202307010109
# skipped:202307010110
# skipped:202307010111
# skipped:202307010112
# skipped:202306010201
# skipped:202306010202
# skipped:202306010203
# skipped:202306010204
# skipped:202306010205
# skipped:202306010206
# skipped:202306010207
# skipped:202306010208
# skipped:202306010209
# skipped:202306010210
# skipped:202306010211
# skipped:202306010212
# skipped:202307010201
# skipped:202307010202
# skipped:202307010203
# skipped:202307010204
# skipped:202307010205
# ...

# %%
#html_paths_raceが失われた場合はファイルから読み込む
#html_paths_raceが失われた場合はファイルから読み込む
if "html_paths_race" not in locals():
    html_paths_race=list(scraping.HTML_RACE_DIR.glob("*bin"))

# %%
html_paths_race
# Out:
# [PosixPath('../data/html/race/202406010111.bin'),
#  PosixPath('../data/html/race/202309020109.bin'),
#  PosixPath('../data/html/race/202303020408.bin'),
#  PosixPath('../data/html/race/202307020402.bin'),
#  PosixPath('../data/html/race/202410020205.bin'),
#  PosixPath('../data/html/race/202308010304.bin'),
#  PosixPath('../data/html/race/202304040412.bin'),
#  PosixPath('../data/html/race/202305020202.bin'),
#  PosixPath('../data/html/race/202309040111.bin'),
#  PosixPath('../data/html/race/202302020503.bin'),
#  PosixPath('../data/html/race/202408020609.bin'),
#  PosixPath('../data/html/race/202304010102.bin'),
#  PosixPath('../data/html/race/202309040909.bin'),
#  PosixPath('../data/html/race/202410030212.bin'),
#  PosixPath('../data/html/race/202308011106.bin'),
#  PosixPath('../data/html/race/202306040108.bin'),
#  PosixPath('../data/html/race/202310020412.bin'),
#  PosixPath('../data/html/race/202307010403.bin'),
#  PosixPath('../data/html/race/202310030709.bin'),
# ...

# %%
results=create_rawdf.create_results(html_path_list=html_paths_race)
# Out:
#   0%|          | 0/6910 [00:00<?, ?it/s]
# table not found at 202408050402
# table not found at 202404010605
# table not found at 202408050309
# table not found at 202403020808
# table not found at 202404030601
# table not found at 202403030411
# table not found at 202410020705
# table not found at 202407020506
# table not found at 202408050605
# table not found at 202407020105
# table not found at 202410020704
# table not found at 202405040203
# table not found at 202403030203
# table not found at 202407030103
# table not found at 202408050601
# table not found at 202403020501
# table not found at 202408060604
# table not found at 202408060506
# table not found at 202408050304
# table not found at 202404040602
# table not found at 202404040101
# table not found at 202403030603
# table not found at 202407030601
# table not found at 202406040704
# table not found at 202403030104
# table not found at 202405040108
# table not found at 202408070602
# table not found at 202404040406
# ...

# %%
#欠損チェック
results
# Out:
#               着順  枠番  馬番         馬名  性齢    斤量    騎手     タイム   着差 ﾀｲﾑ指数  ...  \
# race_id                                                                 ...
# 202406010111   1   2   3    リカンカブール  牡5  56.0  津村明秀  1:58.9  NaN    **  ...
# 202406010111   2   4   7        ククナ  牝6  54.0  戸崎圭太  1:59.0  1/2    **  ...
# 202406010111   3   8  15  マイネルクリソーラ  牡5  55.0  Ｍ．デム  1:59.1   クビ    **  ...
# 202406010111   4   4   8  ボーンディスウェイ  牡5  55.0  木幡巧也  1:59.2  3/4    **  ...
# 202406010111   5   6  12   ホウオウアマゾン  牡6  58.0  横山武史  1:59.3  1/2    **  ...
# ...           ..  ..  ..        ...  ..   ...   ...     ...  ...   ...  ...
# 202408060704   7   8  11     ノーティアス  牡5  60.0  五十嵐雄  3:25.0    大   NaN  ...
# 202408060704   8   4   4     ソルトロング  牡3  58.0  小野寺祐  3:25.5    3   NaN  ...
# 202408060704   9   6   7  ホウオウエクレール  牡7  60.0  小牧加矢  3:28.8    大   NaN  ...
# 202408060704  10   8  10    バルミュゼット  牡5  60.0   森一馬  3:37.0    大   NaN  ...
# ...

# %%
#重複チェック
results.reset_index()[["race_id","horse_id"]].duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## horseページからのデータの取得

# %%
horse_id_list=results["horse_id"].unique()

# %%
html_paths_horse=scraping.scrape_html_horse(horse_id_list=horse_id_list, skip=True)
# Out:
#   0%|          | 0/16708 [00:00<?, ?it/s]
# skipped:2019103823
# skipped:2018105008
# skipped:2019100792
# skipped:2019104658
# skipped:2018105192
# skipped:2017103201
# skipped:2019102879
# skipped:2016104711
# skipped:2020105744
# skipped:2015100744
# skipped:2019105532
# skipped:2017103751
# skipped:2017104756
# skipped:2020106967
# skipped:2017102897
# skipped:2016104319
# skipped:2020105631
# skipped:2020102873
# skipped:2020104739
# skipped:2020105655
# skipped:2020103648
# skipped:2020102688
# skipped:2020103655
# skipped:2020105615
# skipped:2020103255
# skipped:2020109003
# skipped:2020102563
# skipped:2020103565
# skipped:2020103928
# skipped:2020101557
# skipped:2020103225
# skipped:2020105656
# skipped:2019106251
# skipped:2020103052
# skipped:2018102151
# skipped:2019106088
# skipped:2019105341
# skipped:2019105755
# skipped:2018102144
# skipped:2020105201
# skipped:2018105030
# skipped:2016102615
# skipped:2020102646
# skipped:2020100806
# skipped:2020101268
# ...

# %%
#html_paths_horseが失われた場合はファイルから読み込む
if "html_paths_horse" not in locals():
    html_paths_horse=list(scraping.HTML_HORSE_DIR.glob("*bin"))

# %%
#馬の過去成績テーブルの作成
horse_results=create_rawdf.create_horse_results(html_paths_horse)
# Out:
#   0%|          | 0/15004 [00:00<?, ?it/s]
# table not found at 2022102280
# table not found at 2022102839
# table not found at 2022107013
# table not found at 2022103234
# table not found at 2022104496
# table not found at 2022103483
# table not found at 2022101421
# table not found at 2022110139
# table not found at 2022101114
# table not found at 2022107006
# table not found at 2022104983
# table not found at 2022110094
# table not found at 2022101947
# table not found at 2022106164
# table not found at 2022103052
# table not found at 2022107016
# table not found at 2022102874
# table not found at 2022103495
# table not found at 2022101819
# table not found at 2022100345
# table not found at 2022101152
# table not found at 2022100652
# table not found at 2022101255
# table not found at 2022107250
# table not found at 2022105650
# table not found at 2022105042
# table not found at 2022100521
# table not found at 2022103156
# table not found at 2022104583
# ...

# %%
#欠損値チェック
horse_results.index.unique()

#重複チェック
# Out:
# Index(['2021105423', '2020102383', '2020101200', '2022101578', '2018101744',
#        '2022104717', '2021105597', '2019103346', '2021105148', '2020104491',
#        ...
#        '2021103506', '2022103237', '2020103675', '2022100982', '2021109016',
#        '2018104665', '2018104835', '2017100240', '2021105557', '2022106696'],
#       dtype='object', name='horse_id', length=14973)

# %% [markdown]
# ##  レース情報の取得

# %%
import create_rawdf

#html_paths_raceが失われた場合はファイルから読み込む
if "html_paths_race" not in locals():
    html_paths_race=list(scraping.HTML_RACE_DIR.glob("*bin"))

race_info=create_rawdf.create_race_info(html_paths_race)
# Out:
#   0%|          | 0/6910 [00:00<?, ?it/s]

# %%
race_info
# Out:
#           race_id          title  \
# 0    202405050102          2歳未勝利
# 1    202405050103          2歳未勝利
# 2    202405050104          2歳未勝利
# 3    202405050105           2歳新馬
# 4    202405050106           2歳新馬
# ..            ...            ...
# 545  202408070908      3歳以上1勝クラス
# 546  202408070909       春待月賞(2勝)
# 547  202408070910  フォーチュンカップ(2勝)
# 548  202408070911     ベテルギウスS(L)
# 549  202408070912   カウントダウンS(3勝)
#
#                                             info1  \
# 0                 [芝左1600m, 天候:雨, 芝:稍重, 発走:10:25]
# 1                [ダ左1400m, 天候:雨, ダート:重, 発走:10:55]
# 2                [芝左1800m, 天候:小雨, 芝:稍重, 発走:11:25]
# 3                [芝左2000m, 天候:小雨, 芝:稍重, 発走:12:15]
# 4               [ダ左1600m, 天候:小雨, ダート:重, 発走:12:45]
# ..                                            ...
# 545              [ダ右1800m, 天候:晴, ダート:良, 発走:13:40]
# 546     [ダ右1400m, 天候:晴, ダート:良, 発走:14:15, 過去の春待月賞]
# 547  [芝右2000m, 天候:晴, 芝:良, 発走:14:50, 過去のフォーチュンカップ]
# 548  [ダ右1800m, 天候:晴, ダート:良, 発走:15:30, 過去のベテルギウスS]
# ...

# %% [markdown]
# ##  予想

# %%
import create_prediction_population
# %load_ext autoreload

# %%
autoreload

# %%
prediction_population=create_prediction_population.create(kaisai_date="20250215")
# Out:
# scraping race_id_list...
#   0%|          | 0/1 [00:00<?, ?it/s]
# scraping horse_id_list...
#   0%|          | 0/36 [00:00<?, ?it/s]

# %%
prediction_population
# Out:
#          date       race_id    horse_id
# 0  2025-02-15  202505010501  2022100749
# 1  2025-02-15  202505010501  2022106071
# 2  2025-02-15  202505010501  2022107077
# 3  2025-02-15  202505010501  2022102769
# 4  2025-02-15  202505010501  2022106894
# ..        ...           ...         ...
# 7  2025-02-15  202510010712  2021100238
# 8  2025-02-15  202510010712  2021104276
# 9  2025-02-15  202510010712  2020102559
# 10 2025-02-15  202510010712  2021100752
# 11 2025-02-15  202510010712  2020106922
#
# [509 rows x 3 columns]

# %%
html_paths_horse=scraping.scrape_html_horse(
    horse_id_list=prediction_population["horse_id"].unique(),
    skip=False)
# Out:
#   0%|          | 0/509 [00:00<?, ?it/s]

# %%
import create_rawdf
horse_results_prediction=create_rawdf.create_horse_results(
    html_path_list=html_paths_horse,
    save_filename="horse_results_prediction.csv"
)
# Out:
#   0%|          | 0/509 [00:00<?, ?it/s]
# table not found at 2022104107
# table not found at 2022102714
# table not found at 2022109099
# table not found at 2022102847
# table not found at 2022100805
# table not found at 2022103274
# table not found at 2022106396
# table not found at 2022104522
# table not found at 2022101816
# table not found at 2022101956
# table not found at 2022106133
# table not found at 2022106232
# table not found at 2022106964
# table not found at 2022102873
# table not found at 2022104055
# table not found at 2022105494
# table not found at 2022101141
# table not found at 2022105962
# table not found at 2022102902
# table not found at 2022102207
# table not found at 2022101295
# table not found at 2022102426
# table not found at 2022105325
# table not found at 2022105064
# table not found at 2022106083
# table not found at 2022101020
# table not found at 2022110150
# table not found at 2022100844
# table not found at 2022105533
# ...
